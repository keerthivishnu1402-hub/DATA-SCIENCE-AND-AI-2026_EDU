# %% [markdown]
# ### **Python String Indexing Questions**
# text = "Edukron Data Science and Data Engineering Batch 2026"

# %% [markdown]
# 1. **Write the indexing expression to print "Edukron"**.

# %% [markdown]
# Answer 1:

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[0:7])
# Out:
# Edukron

# %% [markdown]
# Answer 2:

# %%
print(text[-52:-45])
# Out:
# Edukron

# %% [markdown]
# Alternate answer:

# %%
print(str("Edukron"))
# Out:
# Edukron

# %% [markdown]
# 2. **Write the indexing expression to print "Data"** (first occurrence).

# %% [markdown]
# Answer 1:

# %%
print(text[8:13])
# Out:
# Data

# %% [markdown]
# Answer 2:

# %%
print(text[-44:-40])
# Out:
# Data

# %% [markdown]
# Alternate answer:

# %%
print(str("Data"))
# Out:
# Data

# %% [markdown]
# 3. **Write the indexing expression to print "Science"**.

# %% [markdown]
# Answer 1:

# %%
print(text[13:20])
# Out:
# Science

# %% [markdown]
# Answer 2:

# %%
print(text[-39:-32])
# Out:
# Science

# %% [markdown]
# Alternate answer:

# %%
print(str("Science"))
# Out:
# Science

# %% [markdown]
# 4. **Write the indexing expression to print "and"**

# %% [markdown]
# Answer 1:

# %%
print(text[21:24])
# Out:
# and

# %% [markdown]
# ANswer 2

# %%
print(text[-31:-28])
# Out:
# and

# %% [markdown]
# Alternate answer

# %%
print(str("and"))
# Out:
# and

# %% [markdown]
# 5. **Write the indexing expression to print "Data Engineering"**.

# %% [markdown]
# Answer 1:

# %%
print(text[25:41])
# Out:
# Data Engineering

# %% [markdown]
# Answer 2:

# %%
print(text[-27:-11])
# Out:
# Data Engineering

# %% [markdown]
# Alternate answer

# %%
print(str("Data Engineering"))
# Out:
# Data Engineering

# %% [markdown]
# 6. **Write the indexing expression to print "Engineering"**.

# %% [markdown]
# Answer 1:

# %%
print(text[30:41])
# Out:
# Engineering

# %% [markdown]
# Answer 2:

# %%
print(text[-22:-11])
# Out:
# Engineering

# %% [markdown]
# Alternate answer:

# %%
print(str("Engineering"))
# Out:
# Engineering

# %% [markdown]
# 7. **Write the indexing expression to print "Batch"**.

# %% [markdown]
# Answer 1:

# %%
print(text[42:47])
# Out:
# Batch

# %% [markdown]
# Answer 2:

# %%
print(text[-10:-5])
# Out:
# Batch

# %% [markdown]
# Alternate answer

# %%
print(str("Batch"))
# Out:
# Batch

# %% [markdown]
# 8. **Write the indexing expression to print "2026"**

# %% [markdown]
# Answer 1:

# %%
print(text[48:52])
# Out:
# 2026

# %% [markdown]
# Answer 2:

# %%
print(text[-4:])
# Out:
# 2026

# %%
print(int('2026'))
# Out:
# 2026

# %% [markdown]
# 9. **Write the indexing expression to print "Science and Data"**.

# %% [markdown]
# Answer 1:

# %%
print(text[13:29])
# Out:
# Science and Data

# %% [markdown]
# Answer 2:

# %%
print(text[-39:-23])
# Out:
# Science and Data

# %% [markdown]
# Alternate answer:

# %%
print(str('Science and Data'))
# Out:
# Science and Data

# %% [markdown]
# 10. **Write the indexing expression to print "Data Science and Data Engineering Batch"**.

# %% [markdown]
# Answer 1:

# %%
print(text[8:41])
# Out:
# Data Science and Data Engineering

# %% [markdown]
# Answer 2:

# %%
print(text[-44:-11])
# Out:
# Data Science and Data Engineering

# %%
print(text[-44:48])
# Out:
# Data Science and Data Engineering Batch

# %% [markdown]
# Alternate answer:

# %%
print(str("Data Science and Data Engineering Batch"))
# Out:
# Data Science and Data Engineering Batch
